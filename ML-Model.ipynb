# %% [markdown]
# Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.linear_model as LinearRegression
import sklearn.model_selection as train_test_split
import sklearn.model_selection as cross_val_score
import sklearn as metrics
print('Libraries imported')
# Out:
# Libraries imported

# %% [markdown]
# Opening the dataset

# %%
df=pd.read_csv(r'C:\Users\ALI HAMZA\Desktop\Python-3\ML-Projects\Linear-Regression\Simple-Salary-Pridiction-Model\DataSet\Salary_dataset.csv')
print('Data Set Imported')
# Out:
# Data Set Imported

# %% [markdown]
# Exploring the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.tail()
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %% [markdown]
# EDA

# %%
plt.bar(df['YearsExperience'],  df['Salary'])
plt.xlabel('Year of Experience')
plt.ylabel('Salary')
plt.grid()
plt.title('Histogram')
plt.show()

# %%
plt.scatter(df['YearsExperience'],  df['Salary'])
plt.xlabel('Year of Experience')
plt.ylabel('Salary')
plt.grid()
plt.title('Histogram')
plt.show()

# %% [markdown]
# Makign the Dependent and Independent Variables

# %%
x=df[['YearsExperience']]
x.head()
# Out:
#    YearsExperience
# 0              1.2
# 1              1.4
# 2              1.6
# 3              2.1
# 4              2.3

# %%
y=df['Salary']
y.head()
# Out:
# 0    39344.0
# 1    46206.0
# 2    37732.0
# 3    43526.0
# 4    39892.0
# Name: Salary, dtype: float64

# %% [markdown]
# Building the model

# %%
from sklearn.model_selection import train_test_split
X_train, x_test ,Y_train ,y_test=train_test_split(x,y, test_size=0.2, random_state=40)

# %%
model=LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train, Y_train, color='blue')
plt.plot(X_train, model.predict(X_train), color='red')  
plt.xlabel('Year of Experience')
plt.ylabel('Salary')
plt.grid()
plt.title('Training Set')
plt.show()

# %%
plt.scatter(x_test, y_test)
plt.show()

# %%
Model_prediction=model.predict(x_test)
Model_prediction
# Out:
# array([41435.13316677, 74802.31604849, 83144.11176892, 69241.11890153,
#        72948.58366617, 65533.6541369 ])

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, Model_prediction)
plt.show()

# %%
from sklearn import metrics

mse=metrics.mean_absolute_error(y_test,Model_prediction)
print(mse)
mse=metrics.mean_squared_error(y_test,Model_prediction)
print(mse)
# Out:
# 7477.11569182384
# 61641413.30887985
